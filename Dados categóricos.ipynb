# %%
import pandas as pd
import numpy as np

caminho = 'C:/Users/Usuario/Documents/arquivos_de_exercicios_python_para_ciencia_dados_basico/dados/mtcars.csv'
carros = pd.read_csv(caminho)
carros.columns = ['nomes','mpg','cyl','disp', 'hpt', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
carros.index = carros.nomes

# %%
carros_cat = carros[['cyl', 'am', 'gear', 'carb']]

# %%
marchasgp = carros_cat.groupby('gear')
marchasgp.describe().T
# Out:
# gear                3          4         5
# cyl  count  15.000000  12.000000  5.000000
#      mean    7.466667   4.666667  6.000000
#      std     1.187234   0.984732  2.000000
#      min     4.000000   4.000000  4.000000
#      25%     8.000000   4.000000  4.000000
#      50%     8.000000   4.000000  6.000000
#      75%     8.000000   6.000000  8.000000
#      max     8.000000   6.000000  8.000000
# am   count  15.000000  12.000000  5.000000
#      mean    0.000000   0.666667  1.000000
#      std     0.000000   0.492366  0.000000
#      min     0.000000   0.000000  1.000000
#      25%     0.000000   0.000000  1.000000
#      50%     0.000000   1.000000  1.000000
#      75%     0.000000   1.000000  1.000000
#      max     0.000000   1.000000  1.000000
# carb count  15.000000  12.000000  5.000000
#      mean    2.666667   2.333333  4.400000
#      std     1.175139   1.302678  2.607681
#      min     1.000000   1.000000  2.000000
#      25%     2.000000   1.000000  2.000000
# ...

# %% [markdown]
# ## Transformando dados em variáveis categóricas

# %%
carros['grupo'] = pd.Series(carros['gear'], dtype='category')

# %%
carros.dtypes
# Out:
# nomes      object
# mpg       float64
# cyl         int64
# disp      float64
# hpt         int64
# drat      float64
# wt        float64
# qsec      float64
# vs          int64
# am          int64
# gear        int64
# carb        int64
# grupo    category
# dtype: object

# %%
carros['grupos'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grupos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-af7550b769d7> in <module>
# ----> 1 carros['grupos'].head()
#
# ...
