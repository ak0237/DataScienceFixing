# %%
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns

# %%
# %matplotlib inline
rcParams ['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

# %% [markdown]
# **Desenhando gráfico de linha usando matplotlib**

# %%
x = range(1,10)
y = [1, 2, 3, 4, 14, 22, 36, 22, 21]

plt.plot(x, y)

# %% [markdown]
# **Desenhando gráfico de linha usando pandas**

# %%
caminho = 'C:/Users/Usuario/Documents/arquivos_de_exercicios_python_para_ciencia_dados_basico/dados/mtcars.csv'

carros = pd.read_csv(caminho)
carros.columns = ['nomes','mpg','cyl','disp', 'hpt', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
df = carros[['cyl', 'mpg', 'wt']]
df.plot()
# Out:
# <AxesSubplot:>
